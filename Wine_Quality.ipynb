# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghu6798/Raghu6798/blob/main/Wine_Quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Read the CSV file
df = pd.read_csv('/content/winequality-red.csv')

# Train test split
X = df.drop('quality', axis=1)
Y = df['quality'].apply(lambda y_value: 1 if y_value >= 7 else 0)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

# Model Training
model = RandomForestClassifier()
model.fit(X_train, Y_train)

# Model evaluation
X_test_prediction = model.predict(X_test)
X_test_accuracy = accuracy_score(X_test_prediction, Y_test)
print("Accuracy:", X_test_accuracy)

# Input data for prediction
input_data = [[8.1,0.38,0.28,2.1,0.066,13.0,30.0,0.9968,3.23,0.73,9.7]]
prediction = model.predict(input_data)
if(prediction == 1) :
    print("Perfect Quality ")
else :
    print("Low quality")
# Out:
# Accuracy: 0.91875
# Perfect Quality
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
